# %% [markdown]
# ### imports

# %%
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### File reading

# %%
filepath='C:\\Users\\hunra\\OneDrive\\Desktop\\PythonForJupiter\\iris.csv'
col_name_list = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
Iris_data =  pd.read_csv(filepath, names = col_name_list)
Iris_data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sliced_df = Iris_data.loc[:, ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']]
print(sliced_df)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
print(Iris_data.shape)
# Out:
# (150, 5)

# %%
Iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Species      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
Iris_data.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# #### Data Visualization

# %%
sns.set_theme(style="ticks")
sns.pairplot(Iris_data,hue = 'Species')
# Out:
# F:\Program-Files\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# F:\Program-Files\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# F:\Program-Files\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# F:\Program-Files\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(7,5))
sns.heatmap(sliced_df.corr(), annot=True, cmap='cubehelix_r')
plt.show()

# %% [markdown]
# #### DataSplitting

# %%
Iris_data_df_to_array = Iris_data.to_numpy()

# %%
print(Iris_data_df_to_array[0,:])
# Out:
# [5.1 3.5 1.4 0.2 'Iris-setosa']

# %%
# Feature Matrix
X = Iris_data_df_to_array[:, :(len(Iris_data_df_to_array[0,:])-1)]

# %%
# Target Matrix
y = Iris_data_df_to_array[:,4]
print(y)
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica']

# %% [markdown]
# #### Model Validation

# %%
# Data Splitting between training set and test set(Validation Data)
train_X, val_X, train_y, val_y = train_test_split(X,y,random_state = 0)

# %% [markdown]
# #### Model Building and Prediction

# %%
# model definition
iris_model = LogisticRegression()

# %%
# model fitting
iris_model.fit(train_X,train_y)
# Out:
# LogisticRegression()

# %%
# model prediction
val_predictions = iris_model.predict(val_X)
val_predictions
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %%
# Creating Prediction DataFrame Table
predicted_df = pd.DataFrame(val_X ,columns=['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth'])
predicted_df["Predicted Species"] = val_predictions
predicted_df["Actual Species"] = val_y
predicted_df['True State'] = (val_y == val_predictions).reshape(len(val_predictions),1)
#print((val_y == val_predictions).shape)
predicted_df
# Out:
# (38,)
#    SepalLength SepalWidth PetalLength PetalWidth Predicted Species  \
# 0          5.8        2.8         5.1        2.4    Iris-virginica
# 1          6.0        2.2         4.0        1.0   Iris-versicolor
# 2          5.5        4.2         1.4        0.2       Iris-setosa
# 3          7.3        2.9         6.3        1.8    Iris-virginica
# 4          5.0        3.4         1.5        0.2       Iris-setosa
# 5          6.3        3.3         6.0        2.5    Iris-virginica
# 6          5.0        3.5         1.3        0.3       Iris-setosa
# 7          6.7        3.1         4.7        1.5   Iris-versicolor
# 8          6.8        2.8         4.8        1.4   Iris-versicolor
# 9          6.1        2.8         4.0        1.3   Iris-versicolor
# 10         6.1        2.6         5.6        1.4    Iris-virginica
# 11         6.4        3.2         4.5        1.5   Iris-versicolor
# 12         6.1        2.8         4.7        1.2   Iris-versicolor
# 13         6.5        2.8         4.6        1.5   Iris-versicolor
# 14         6.1        2.9         4.7        1.4   Iris-versicolor
# 15         4.9        3.1         1.5        0.1       Iris-setosa
# 16         6.0        2.9         4.5        1.5   Iris-versicolor
# 17         5.5        2.6         4.4        1.2   Iris-versicolor
# 18         4.8        3.0         1.4        0.3       Iris-setosa
# 19         5.4        3.9         1.3        0.4       Iris-setosa
# 20         5.6        2.8         4.9        2.0    Iris-virginica
# 21         5.6        3.0         4.5        1.5   Iris-versicolor
# 22         4.8        3.4         1.9        0.2       Iris-setosa
# 23         4.4        2.9         1.4        0.2       Iris-setosa
# 24         6.2        2.8         4.8        1.8    Iris-virginica
# 25         4.6        3.6         1.0        0.2       Iris-setosa
# 26         5.1        3.8         1.9        0.4       Iris-setosa
# 27         6.2        2.9         4.3        1.3   Iris-versicolor
# 28         5.0        2.3         3.3        1.0   Iris-versicolor
# 29         5.0        3.4         1.6        0.4       Iris-setosa
# 30         6.4        3.1         5.5        1.8    Iris-virginica
# 31         5.4        3.0         4.5        1.5   Iris-versicolor
# 32         5.2        3.5         1.5        0.2       Iris-setosa
# 33         6.1        3.0         4.9        1.8    Iris-virginica
# 34         6.4        2.8         5.6        2.2    Iris-virginica
# 35         5.2        2.7         3.9        1.4   Iris-versicolor
# 36         5.7        3.8         1.7        0.3       Iris-setosa
# 37         6.0        2.7         5.1        1.6    Iris-virginica
#
#      Actual Species  True State
# 0    Iris-virginica        True
# 1   Iris-versicolor        True
# 2       Iris-setosa        True
# 3    Iris-virginica        True
# 4       Iris-setosa        True
# 5    Iris-virginica        True
# 6       Iris-setosa        True
# 7   Iris-versicolor        True
# 8   Iris-versicolor        True
# 9   Iris-versicolor        True
# 10   Iris-virginica        True
# 11  Iris-versicolor        True
# 12  Iris-versicolor        True
# 13  Iris-versicolor        True
# 14  Iris-versicolor        True
# 15      Iris-setosa        True
# 16  Iris-versicolor        True
# 17  Iris-versicolor        True
# 18      Iris-setosa        True
# 19      Iris-setosa        True
# 20   Iris-virginica        True
# 21  Iris-versicolor        True
# 22      Iris-setosa        True
# 23      Iris-setosa        True
# 24   Iris-virginica        True
# 25      Iris-setosa        True
# 26      Iris-setosa        True
# 27  Iris-versicolor        True
# 28  Iris-versicolor        True
# 29      Iris-setosa        True
# 30   Iris-virginica        True
# 31  Iris-versicolor        True
# 32      Iris-setosa        True
# 33   Iris-virginica        True
# 34   Iris-virginica        True
# 35  Iris-versicolor        True
# 36      Iris-setosa        True
# 37  Iris-versicolor       False

# %% [markdown]
# #### Accuracy Testing

# %%
truth_state_series = pd.Series(val_predictions == val_y)
print(truth_state_series)
total_test_count = len(val_y)
hit_count = len(truth_state_series[truth_state_series == True])
miss_count = len(truth_state_series[truth_state_series == False])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37    False
# dtype: bool

# %%
def accuracy(hit=0,total_test=0):
    return (hit/total_test)*100

# %%
print('--',hit_count, '-- prediction out of --', total_test_count,\
    '-- was HIT and --', miss_count,'-- MISSED with hit rate of --',\
    accuracy(hit=hit_count,total_test=total_test_count),' %--', sep = '')
# Out:
# --37-- prediction out of --38-- was HIT and --1-- MISSED with hit rate of --97.36842105263158 %--

# %% [markdown]
# #### Using Your Model

# %%
def testSpecies(sepalLength = 0, sepalWidth = 0, petalLength = 0, petalWidth = 0):
    features = np.array([[sepalLength , sepalWidth , petalLength , petalWidth ]])
    val_predictions = iris_model.predict(features)
    return val_predictions[0]

# %%
print('Enter The Following Details To Know Your Species: ')
sepalLength = eval(input("Enter SepalLength = "))
sepalWidth = eval(input("Enter SepalWidth = "))
petalLength = eval(input("Enter PetalLength = "))
petalWidth = eval(input("Enter PeralWidth = "))
print("The Predicted Sepcies Of The Features Your Enter is",\
testSpecies(sepalLength = sepalLength, sepalWidth = sepalWidth,  petalLength = petalLength, petalWidth = petalWidth))
# Out:
# Enter The Following Details To Know Your Species:
# Enter SepalLength =  3
# Enter SepalWidth =  4.4
# Enter PetalLength =  3.4
# Enter PeralWidth =  5.0
# The Predicted Sepcies Of The Features Your Enter is Iris-virginica
